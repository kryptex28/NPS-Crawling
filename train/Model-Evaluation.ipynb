# %%
import pandas as pd

df = pd.read_excel(r"C:\Users\silas\Documents\ISY1\NPS-Crawling\Mapping_Manuell_V2_Ellena_diff_marked.xlsx", sheet_name="Filings")
df = df.replace("N/A", -1).fillna(-1)
df.to_csv(
    r".\data\Mapping_Manuell_V2_Ellena.csv",
    index=False
)

# %%
from sklearn.model_selection import train_test_split
import pandas as pd
df = pd.read_csv(r".\data\Mapping_Manuell_V2_Ellena.csv")
train_df, test_df = train_test_split(df, test_size=0.2, random_state=42)

# %%
from nps_crawling.classification.model_new import ClassificationClass, get_model_class
from nps_crawling.classification.options import (
    ClassificationOptionName,
    get_classification_option
)
option = get_classification_option(ClassificationOptionName.NPS_CATEGORY)
model_class = get_model_class(ClassificationClass.SVM, {"model":"BAAI/bge-m3"})
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from nps_crawling.classification.model_new import ClassificationClass, get_model_class
#       2 from nps_crawling.classification.options import (
#       3     ClassificationOptionName,
#       4     get_classification_option
#       5 )
#       6 option = get_classification_option(ClassificationOptionName.NPS_CATEGORY)
#
# File ~\VSProjects\NPS-Crawling\src\nps_crawling\classification\__init__.py:3
#       1 """Classification package initialization."""
# ----> 3 from nps_crawling.classification.utils import ClassificationPipeline as ClassificationPipeline
#
# File ~\VSProjects\NPS-Crawling\src\nps_crawling\classification\utils.py:6
#       3 import json
#       4 import logging
# ----> 6 from nps_crawling.classification.data_processing.preprocess_data import ClassificationDataProcessing
#       7 from nps_crawling.classification.model.classification import ClassificationModelPipeline
#       8 from nps_crawling.config import Config
#
# File ~\VSProjects\NPS-Crawling\src\nps_crawling\classification\data_processing\preprocess_data.py:6
#       3 import json
#       4 import re
# ----> 6 from nps_crawling.config import Config
#       9 class ClassificationDataProcessing(Config):
#      10     """Data processing class for classification tasks."""
#
# File ~\VSProjects\NPS-Crawling\src\nps_crawling\config.py:7
#       5 import os
#       6 from dotenv import load_dotenv
# ----> 7 from nps_crawling.classification.model import ClassificationClass
#       9 load_dotenv()
#      11 def get_git_root() -> Path:
#
# ImportError: cannot import name 'ClassificationClass' from 'nps_crawling.classification.model' (C:\Users\silas\VSProjects\NPS-Crawling\src\nps_crawling\classification\model\__init__.py)

# %%
for property in option.get_classification_properties():
    model_class.train(classification_property=property, texts=train_df["snippet_text_short"].to_list(), labels=train_df[property.name].to_list())

# %%
for property in option.get_classification_properties():
    model_class.evaluate(option, property, texts=test_df["snippet_text_short"].to_list(), labels=test_df[property.name].to_list())
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.67      0.70        58
#            1       0.71      0.77      0.74        60
#
#     accuracy                           0.72       118
#    macro avg       0.72      0.72      0.72       118
# weighted avg       0.72      0.72      0.72       118
#
#               precision    recall  f1-score   support
#
#            0       0.83      0.92      0.87        85
#            1       0.71      0.52      0.60        33
#
#     accuracy                           0.81       118
#    macro avg       0.77      0.72      0.73       118
# weighted avg       0.80      0.81      0.79       118
#
#               precision    recall  f1-score   support
#
#            0       0.82      0.87      0.84        84
#            1       0.62      0.53      0.57        34
#
#     accuracy                           0.77       118
#    macro avg       0.72      0.70      0.71       118
# weighted avg       0.76      0.77      0.77       118
#
#               precision    recall  f1-score   support
#
#            0       0.86      0.78      0.82        87
#            1       0.51      0.65      0.57        31
#
#     accuracy                           0.75       118
#    macro avg       0.69      0.71      0.70       118
# weighted avg       0.77      0.75      0.75       118
# c:\Users\silas\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\silas\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\silas\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\silas\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\silas\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\silas\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       117
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.99       118
#    macro avg       0.50      0.50      0.50       118
# weighted avg       0.98      0.99      0.99       118
#
#               precision    recall  f1-score   support
#
#            0       0.97      0.95      0.96       110
#            1       0.50      0.62      0.56         8
#
#     accuracy                           0.93       118
#    macro avg       0.74      0.79      0.76       118
# weighted avg       0.94      0.93      0.94       118
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00       111
#            1       0.88      1.00      0.93         7
#
#     accuracy                           0.99       118
#    macro avg       0.94      1.00      0.96       118
# weighted avg       0.99      0.99      0.99       118
#
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99       112
#            1       0.71      0.83      0.77         6
#
#     accuracy                           0.97       118
#    macro avg       0.85      0.91      0.88       118
# weighted avg       0.98      0.97      0.98       118
#
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99       114
#            1       1.00      0.25      0.40         4
#
#     accuracy                           0.97       118
#    macro avg       0.99      0.62      0.69       118
# weighted avg       0.98      0.97      0.97       118
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       114
#            1       1.00      1.00      1.00         4
#
#     accuracy                           1.00       118
#    macro avg       1.00      1.00      1.00       118
# weighted avg       1.00      1.00      1.00       118
#
#               precision    recall  f1-score   support
#
#            0       0.95      0.94      0.94        96
#            1       0.74      0.77      0.76        22
#
#     accuracy                           0.91       118
#    macro avg       0.84      0.86      0.85       118
# weighted avg       0.91      0.91      0.91       118
#
#               precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95       110
#            1       0.29      0.25      0.27         8
#
#     accuracy                           0.91       118
#    macro avg       0.62      0.60      0.61       118
# weighted avg       0.90      0.91      0.90       118
#
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       112
#            1       1.00      0.67      0.80         6
#
#     accuracy                           0.98       118
#    macro avg       0.99      0.83      0.90       118
# weighted avg       0.98      0.98      0.98       118

# %%
from nps_crawling.classification.model_new import ClassificationClass, get_model_class
from nps_crawling.classification.options import (
    ClassificationOptionName,
    get_classification_option
)
option = get_classification_option(ClassificationOptionName.NPS_VALUE)
model_class = get_model_class(ClassificationClass.QAHUGGINGFACE, {"model":"mistralai/Mistral-7B-Instruct-v0.3"})
# Out:
# VRAM: 15.9 GB — NVIDIA GeForce RTX 5070 Ti
# config.json:   0%|          | 0.00/601 [00:00<?, ?B/s]
# c:\Users\silas\anaconda3\Lib\site-packages\huggingface_hub\file_download.py:129: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\silas\.cache\huggingface\hub\models--mistralai--Mistral-7B-Instruct-v0.3. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# tokenizer.json: 0.00B [00:00, ?B/s]
# tokenizer.model:   0%|          | 0.00/587k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 3 files:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
for property in option.get_classification_properties():
    model_class.evaluate(option, property, texts=test_df["snippet_text_short"].to_list(), labels=test_df[property.name].to_list())
